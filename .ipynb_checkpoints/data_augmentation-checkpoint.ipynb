# %%
import cv2
import os
import numpy as np
import random

# %%
# Function to flip the frames horizontally
def flip_frame(frame):
    return cv2.flip(frame, 1)

# %%
# Function to rotate the frame
def rotate_frame(frame, angle=15):
    (h, w) = frame.shape[:2]
    center = (w // 2, h // 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    return cv2.warpAffine(frame, matrix, (w, h))

# %%
# Function to change brightness of the frame
def adjust_brightness(frame, factor=1.5):
    return cv2.convertScaleAbs(frame, alpha=factor, beta=0)

# %%
# Function to add random noise to the frame
def add_noise(frame):
    noise = np.random.normal(0, 25, frame.shape).astype(np.uint8)
    return cv2.add(frame, noise)

# %%
# Directory paths
original_videos_path = "words"  # Original videos directory
augmented_videos_path = "augmented-videos"  # Directory to save augmented videos

# %%
# Function to apply augmentations to video
def augment_video(video_path, save_path):
    cap = cv2.VideoCapture(video_path)
    
    if not cap.isOpened():
        print(f"Error: Couldn't open video {video_path}")
        return

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Generate augmented video paths
    base_name = os.path.splitext(os.path.basename(video_path))[0]
    output_files = [
        os.path.join(save_path, f"{base_name}_flip.mp4"),
        os.path.join(save_path, f"{base_name}_rotate.mp4"),
        os.path.join(save_path, f"{base_name}_brightness.mp4"),
        os.path.join(save_path, f"{base_name}_noise.mp4")
    ]

    # Create VideoWriter objects for each augmented video
    writers = [
        cv2.VideoWriter(output_files[0], fourcc, fps, (width, height)),
        cv2.VideoWriter(output_files[1], fourcc, fps, (width, height)),
        cv2.VideoWriter(output_files[2], fourcc, fps, (width, height)),
        cv2.VideoWriter(output_files[3], fourcc, fps, (width, height))
    ]

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Apply different augmentations
        flipped = flip_frame(frame)
        rotated = rotate_frame(frame)
        brightened = adjust_brightness(frame)
        noised = add_noise(frame)

        # Write augmented frames to the respective videos
        writers[0].write(flipped)
        writers[1].write(rotated)
        writers[2].write(brightened)
        writers[3].write(noised)

    # Release everything
    cap.release()
    for writer in writers:
        writer.release()
    
    print(f"Augmented videos saved at {save_path}")

# %%
# Main function to process all subfolders and videos
def process_videos(original_videos_path, augmented_videos_path):
    # Ensure the augmented directory exists
    if not os.path.exists(augmented_videos_path):
        os.makedirs(augmented_videos_path)

    # Iterate through each class folder (subfolder)
    for class_dir in os.listdir(original_videos_path):
        class_path = os.path.join(original_videos_path, class_dir)
        save_class_path = os.path.join(augmented_videos_path, class_dir)

        # Ensure the class subfolder exists in the augmented path
        if not os.path.exists(save_class_path):
            os.makedirs(save_class_path)

        # Process each video in the subfolder
        for video in os.listdir(class_path):
            video_path = os.path.join(class_path, video)
            augment_video(video_path, save_class_path)

# %%
# Call the function to process all videos
process_videos(original_videos_path, augmented_videos_path)
# Out:
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Amilo
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Baisakh
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Falful
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Ghar
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Gundruk
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Guy
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hariyo
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Hathi
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Jestha
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Kera
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Khairo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Kharayo
# Augmented videos saved at augmented-videos\Mahina
# Augmented videos saved at augmented-videos\Mahina
# Augmented videos saved at augmented-videos\Mahina
# Augmented videos saved at augmented-videos\Mahina
# Augmented videos saved at augmented-videos\Mahina
# Augmented videos saved at augmented-videos\Mahina
# Augmented videos saved at augmented-videos\Mahina
# Augmented videos saved at augmented-videos\Mahina
# Augmented videos saved at augmented-videos\Mahina
# Augmented videos saved at augmented-videos\Mahina
# Augmented videos saved at augmented-videos\Mahina

# %%
# Function to change video speed (speed up or slow down)
def adjust_speed(video, factor=1.0):
    if factor > 1.0:
        # Speed up: Skip frames
        return [video[i] for i in range(0, len(video), int(factor))]
    elif factor < 1.0:
        # Slow down: Duplicate frames
        new_video = []
        for frame in video:
            # Duplicate each frame (inverse of factor times)
            new_video.extend([frame] * int(1 / factor))
        return new_video
    else:
        # If factor is 1.0, return video as is
        return video

# %%
# Function to randomly drop frames
def drop_frames(video, drop_probability=0.2):
    return [frame for frame in video if random.random() > drop_probability]

# %%
# Function to apply color jitter (brightness, contrast, saturation)
def color_jitter(frame, brightness=0.2, contrast=0.2, saturation=0.2):
    # Adjust brightness
    frame = cv2.convertScaleAbs(frame, alpha=1 + random.uniform(-brightness, brightness), beta=0)
    
    # Adjust contrast
    frame = cv2.convertScaleAbs(frame, alpha=1 + random.uniform(-contrast, contrast), beta=0)
    
    # Adjust saturation (convert to HSV and modify S channel)
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    hsv[:, :, 1] = np.clip(hsv[:, :, 1] * (1 + random.uniform(-saturation, saturation)), 0, 255)
    frame = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    
    return frame

# %%
# Function to apply augmentations to video frames
def augment_video_frames(frames, augmentation_type):
    augmented_frames = []
    
    for frame in frames:
        if augmentation_type == 'color_jitter':
            augmented_frames.append(color_jitter(frame))
        elif augmentation_type == 'drop_frames':
            # Frame dropping is done at the video level, not per frame
            pass
        else:
            augmented_frames.append(frame)
    
    if augmentation_type == 'speed_up':
        return adjust_speed(augmented_frames, factor=2.0)  # Speed up (skip frames)
    elif augmentation_type == 'slow_down':
        return adjust_speed(augmented_frames, factor=0.5)  # Slow down (duplicate frames)
    elif augmentation_type == 'drop_frames':
        return drop_frames(augmented_frames, drop_probability=0.2)
    else:
        return augmented_frames

# %%
# Function to read video into frames
def read_video(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []

    if not cap.isOpened():
        print(f"Error: Couldn't open video {video_path}")
        return frames

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)

    cap.release()
    return frames

# %%
# Function to save augmented video
def save_video(frames, save_path, original_video_path):
    if len(frames) == 0:
        print(f"No frames to save for {original_video_path}")
        return

    height, width, _ = frames[0].shape
    fps = 20  # Assuming 20 FPS, you can modify this based on your video properties
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(save_path, fourcc, fps, (width, height))

    for frame in frames:
        out.write(frame)

    out.release()
    print(f"Saved augmented video at {save_path}")

# %%
# Main function to process all subfolders and videos
def process_videos2(original_videos_path, augmented_videos_path):
    augmentations = ['speed_up', 'slow_down', 'drop_frames', 'color_jitter']
    
    # Ensure the augmented directory exists
    if not os.path.exists(augmented_videos_path):
        os.makedirs(augmented_videos_path)

    # Iterate through each class folder (subfolder)
    for class_dir in os.listdir(original_videos_path):
        class_path = os.path.join(original_videos_path, class_dir)
        save_class_path = os.path.join(augmented_videos_path, class_dir)

        # Ensure the class subfolder exists in the augmented path
        if not os.path.exists(save_class_path):
            os.makedirs(save_class_path)

        # Process each video in the subfolder
        for video in os.listdir(class_path):
            video_path = os.path.join(class_path, video)
            frames = read_video(video_path)

            for augmentation in augmentations:
                augmented_frames = augment_video_frames(frames, augmentation)
                base_name = os.path.splitext(os.path.basename(video_path))[0]
                save_video_path = os.path.join(save_class_path, f"{base_name}_{augmentation}.mp4")
                save_video(augmented_frames, save_video_path, video_path)

# %%
# Call the function to process all videos
process_videos2(original_videos_path, augmented_videos_path)
# Out:
# Saved augmented video at augmented-videos\Amilo\20241001_152509_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241001_152509_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241001_152509_slow_down.mp4
# No frames to save for words\Amilo\20241001_152509.mp4
# Saved augmented video at augmented-videos\Amilo\20241001_152509_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241002_104402_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241002_104402_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241002_104402_slow_down.mp4
# No frames to save for words\Amilo\20241002_104402.mp4
# Saved augmented video at augmented-videos\Amilo\20241002_104402_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241002_112728_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241002_112728_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241002_112728_slow_down.mp4
# No frames to save for words\Amilo\20241002_112728.mp4
# Saved augmented video at augmented-videos\Amilo\20241002_112728_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241002_121249_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241002_121249_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241002_121249_slow_down.mp4
# No frames to save for words\Amilo\20241002_121249.mp4
# Saved augmented video at augmented-videos\Amilo\20241002_121249_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_085616_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_085616_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_085616_slow_down.mp4
# No frames to save for words\Amilo\20241003_085616.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_085616_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_091237_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_091237_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_091237_slow_down.mp4
# No frames to save for words\Amilo\20241003_091237.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_091237_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_114358_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_114358_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_114358_slow_down.mp4
# No frames to save for words\Amilo\20241003_114358.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_114358_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_115353_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_115353_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_115353_slow_down.mp4
# No frames to save for words\Amilo\20241003_115353.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_115353_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_120921_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_120921_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_120921_slow_down.mp4
# No frames to save for words\Amilo\20241003_120921.mp4
# Saved augmented video at augmented-videos\Amilo\20241003_120921_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241006_084654_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241006_084654_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241006_084654_slow_down.mp4
# No frames to save for words\Amilo\20241006_084654.mp4
# Saved augmented video at augmented-videos\Amilo\20241006_084654_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241006_090618_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241006_090618_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241006_090618_slow_down.mp4
# No frames to save for words\Amilo\20241006_090618.mp4
# Saved augmented video at augmented-videos\Amilo\20241006_090618_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241006_094559_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241006_094559_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241006_094559_slow_down.mp4
# No frames to save for words\Amilo\20241006_094559.mp4
# Saved augmented video at augmented-videos\Amilo\20241006_094559_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241008_091534_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241008_091534_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241008_091534_slow_down.mp4
# No frames to save for words\Amilo\20241008_091534.mp4
# Saved augmented video at augmented-videos\Amilo\20241008_091534_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241008_093927_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241008_093927_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241008_093927_slow_down.mp4
# No frames to save for words\Amilo\20241008_093927.mp4
# Saved augmented video at augmented-videos\Amilo\20241008_093927_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241008_100833_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241008_100833_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241008_100833_slow_down.mp4
# No frames to save for words\Amilo\20241008_100833.mp4
# Saved augmented video at augmented-videos\Amilo\20241008_100833_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241014_092627_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241014_092627_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241014_092627_slow_down.mp4
# No frames to save for words\Amilo\20241014_092627.mp4
# Saved augmented video at augmented-videos\Amilo\20241014_092627_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\20241014_093749_crop.mp4
# Saved augmented video at augmented-videos\Amilo\20241014_093749_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\20241014_093749_slow_down.mp4
# No frames to save for words\Amilo\20241014_093749.mp4
# Saved augmented video at augmented-videos\Amilo\20241014_093749_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\dataset 03 (2)_crop.mp4
# Saved augmented video at augmented-videos\Amilo\dataset 03 (2)_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\dataset 03 (2)_slow_down.mp4
# No frames to save for words\Amilo\dataset 03 (2).mp4
# Saved augmented video at augmented-videos\Amilo\dataset 03 (2)_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\Dataset01 (1)_crop.mp4
# Saved augmented video at augmented-videos\Amilo\Dataset01 (1)_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\Dataset01 (1)_slow_down.mp4
# No frames to save for words\Amilo\Dataset01 (1).mp4
# Saved augmented video at augmented-videos\Amilo\Dataset01 (1)_color_jitter.mp4
# Saved augmented video at augmented-videos\Amilo\Dataset02 (6)_crop.mp4
# Saved augmented video at augmented-videos\Amilo\Dataset02 (6)_speed_up.mp4
# Saved augmented video at augmented-videos\Amilo\Dataset02 (6)_slow_down.mp4
# No frames to save for words\Amilo\Dataset02 (6).mp4
# Saved augmented video at augmented-videos\Amilo\Dataset02 (6)_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241001_152325_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241001_152325_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241001_152325_slow_down.mp4
# No frames to save for words\Baisakh\20241001_152325.mp4
# Saved augmented video at augmented-videos\Baisakh\20241001_152325_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241002_104210_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241002_104210_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241002_104210_slow_down.mp4
# No frames to save for words\Baisakh\20241002_104210.mp4
# Saved augmented video at augmented-videos\Baisakh\20241002_104210_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241002_111535_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241002_111535_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241002_111535_slow_down.mp4
# No frames to save for words\Baisakh\20241002_111535.mp4
# Saved augmented video at augmented-videos\Baisakh\20241002_111535_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241002_121133_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241002_121133_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241002_121133_slow_down.mp4
# No frames to save for words\Baisakh\20241002_121133.mp4
# Saved augmented video at augmented-videos\Baisakh\20241002_121133_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_085517_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_085517_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_085517_slow_down.mp4
# No frames to save for words\Baisakh\20241003_085517.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_085517_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_091207_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_091207_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_091207_slow_down.mp4
# No frames to save for words\Baisakh\20241003_091207.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_091207_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_114239_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_114239_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_114239_slow_down.mp4
# No frames to save for words\Baisakh\20241003_114239.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_114239_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_115256_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_115256_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_115256_slow_down.mp4
# No frames to save for words\Baisakh\20241003_115256.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_115256_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_120831_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_120831_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_120831_slow_down.mp4
# No frames to save for words\Baisakh\20241003_120831.mp4
# Saved augmented video at augmented-videos\Baisakh\20241003_120831_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241006_082424_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241006_082424_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241006_082424_slow_down.mp4
# No frames to save for words\Baisakh\20241006_082424.mp4
# Saved augmented video at augmented-videos\Baisakh\20241006_082424_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241006_090453_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241006_090453_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241006_090453_slow_down.mp4
# No frames to save for words\Baisakh\20241006_090453.mp4
# Saved augmented video at augmented-videos\Baisakh\20241006_090453_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241006_093749_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241006_093749_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241006_093749_slow_down.mp4
# No frames to save for words\Baisakh\20241006_093749.mp4
# Saved augmented video at augmented-videos\Baisakh\20241006_093749_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241008_091447_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241008_091447_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241008_091447_slow_down.mp4
# No frames to save for words\Baisakh\20241008_091447.mp4
# Saved augmented video at augmented-videos\Baisakh\20241008_091447_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241008_093838_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241008_093838_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241008_093838_slow_down.mp4
# No frames to save for words\Baisakh\20241008_093838.mp4
# Saved augmented video at augmented-videos\Baisakh\20241008_093838_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241008_100746_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241008_100746_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241008_100746_slow_down.mp4
# No frames to save for words\Baisakh\20241008_100746.mp4
# Saved augmented video at augmented-videos\Baisakh\20241008_100746_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241014_092505_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241014_092505_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241014_092505_slow_down.mp4
# No frames to save for words\Baisakh\20241014_092505.mp4
# Saved augmented video at augmented-videos\Baisakh\20241014_092505_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\20241014_093646_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\20241014_093646_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\20241014_093646_slow_down.mp4
# No frames to save for words\Baisakh\20241014_093646.mp4
# Saved augmented video at augmented-videos\Baisakh\20241014_093646_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\dataset 03 (6)_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\dataset 03 (6)_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\dataset 03 (6)_slow_down.mp4
# No frames to save for words\Baisakh\dataset 03 (6).mp4
# Saved augmented video at augmented-videos\Baisakh\dataset 03 (6)_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\Dataset01 (8)_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\Dataset01 (8)_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\Dataset01 (8)_slow_down.mp4
# No frames to save for words\Baisakh\Dataset01 (8).mp4
# Saved augmented video at augmented-videos\Baisakh\Dataset01 (8)_color_jitter.mp4
# Saved augmented video at augmented-videos\Baisakh\Dataset02 (8)_crop.mp4
# Saved augmented video at augmented-videos\Baisakh\Dataset02 (8)_speed_up.mp4
# Saved augmented video at augmented-videos\Baisakh\Dataset02 (8)_slow_down.mp4
# No frames to save for words\Baisakh\Dataset02 (8).mp4
# Saved augmented video at augmented-videos\Baisakh\Dataset02 (8)_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241001_152707_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241001_152707_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241001_152707_slow_down.mp4
# No frames to save for words\Falful\20241001_152707.mp4
# Saved augmented video at augmented-videos\Falful\20241001_152707_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241002_104518_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241002_104518_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241002_104518_slow_down.mp4
# No frames to save for words\Falful\20241002_104518.mp4
# Saved augmented video at augmented-videos\Falful\20241002_104518_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241002_111951_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241002_111951_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241002_111951_slow_down.mp4
# No frames to save for words\Falful\20241002_111951.mp4
# Saved augmented video at augmented-videos\Falful\20241002_111951_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241002_121409_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241002_121409_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241002_121409_slow_down.mp4
# No frames to save for words\Falful\20241002_121409.mp4
# Saved augmented video at augmented-videos\Falful\20241002_121409_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241003_085753_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241003_085753_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241003_085753_slow_down.mp4
# No frames to save for words\Falful\20241003_085753.mp4
# Saved augmented video at augmented-videos\Falful\20241003_085753_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241003_091334_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241003_091334_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241003_091334_slow_down.mp4
# No frames to save for words\Falful\20241003_091334.mp4
# Saved augmented video at augmented-videos\Falful\20241003_091334_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241003_114523_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241003_114523_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241003_114523_slow_down.mp4
# No frames to save for words\Falful\20241003_114523.mp4
# Saved augmented video at augmented-videos\Falful\20241003_114523_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241003_115610_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241003_115610_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241003_115610_slow_down.mp4
# No frames to save for words\Falful\20241003_115610.mp4
# Saved augmented video at augmented-videos\Falful\20241003_115610_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241003_121040_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241003_121040_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241003_121040_slow_down.mp4
# No frames to save for words\Falful\20241003_121040.mp4
# Saved augmented video at augmented-videos\Falful\20241003_121040_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241006_083109_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241006_083109_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241006_083109_slow_down.mp4
# No frames to save for words\Falful\20241006_083109.mp4
# Saved augmented video at augmented-videos\Falful\20241006_083109_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241006_090751_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241006_090751_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241006_090751_slow_down.mp4
# No frames to save for words\Falful\20241006_090751.mp4
# Saved augmented video at augmented-videos\Falful\20241006_090751_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241006_094017_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241006_094017_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241006_094017_slow_down.mp4
# No frames to save for words\Falful\20241006_094017.mp4
# Saved augmented video at augmented-videos\Falful\20241006_094017_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241008_091634_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241008_091634_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241008_091634_slow_down.mp4
# No frames to save for words\Falful\20241008_091634.mp4
# Saved augmented video at augmented-videos\Falful\20241008_091634_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241008_094629_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241008_094629_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241008_094629_slow_down.mp4
# No frames to save for words\Falful\20241008_094629.mp4
# Saved augmented video at augmented-videos\Falful\20241008_094629_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241008_100938_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241008_100938_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241008_100938_slow_down.mp4
# No frames to save for words\Falful\20241008_100938.mp4
# Saved augmented video at augmented-videos\Falful\20241008_100938_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241014_092805_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241014_092805_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241014_092805_slow_down.mp4
# No frames to save for words\Falful\20241014_092805.mp4
# Saved augmented video at augmented-videos\Falful\20241014_092805_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\20241014_093907_crop.mp4
# Saved augmented video at augmented-videos\Falful\20241014_093907_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\20241014_093907_slow_down.mp4
# No frames to save for words\Falful\20241014_093907.mp4
# Saved augmented video at augmented-videos\Falful\20241014_093907_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\dataset 03 (8)_crop.mp4
# Saved augmented video at augmented-videos\Falful\dataset 03 (8)_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\dataset 03 (8)_slow_down.mp4
# No frames to save for words\Falful\dataset 03 (8).mp4
# Saved augmented video at augmented-videos\Falful\dataset 03 (8)_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\Dataset01 (15)_crop.mp4
# Saved augmented video at augmented-videos\Falful\Dataset01 (15)_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\Dataset01 (15)_slow_down.mp4
# No frames to save for words\Falful\Dataset01 (15).mp4
# Saved augmented video at augmented-videos\Falful\Dataset01 (15)_color_jitter.mp4
# Saved augmented video at augmented-videos\Falful\Dataset02 (7)_crop.mp4
# Saved augmented video at augmented-videos\Falful\Dataset02 (7)_speed_up.mp4
# Saved augmented video at augmented-videos\Falful\Dataset02 (7)_slow_down.mp4
# No frames to save for words\Falful\Dataset02 (7).mp4
# Saved augmented video at augmented-videos\Falful\Dataset02 (7)_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241001_152853_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241001_152853_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241001_152853_slow_down.mp4
# No frames to save for words\Ghar\20241001_152853.mp4
# Saved augmented video at augmented-videos\Ghar\20241001_152853_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241002_104835_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241002_104835_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241002_104835_slow_down.mp4
# No frames to save for words\Ghar\20241002_104835.mp4
# Saved augmented video at augmented-videos\Ghar\20241002_104835_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241002_112236_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241002_112236_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241002_112236_slow_down.mp4
# No frames to save for words\Ghar\20241002_112236.mp4
# Saved augmented video at augmented-videos\Ghar\20241002_112236_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241002_121601_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241002_121601_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241002_121601_slow_down.mp4
# No frames to save for words\Ghar\20241002_121601.mp4
# Saved augmented video at augmented-videos\Ghar\20241002_121601_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_085912_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_085912_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_085912_slow_down.mp4
# No frames to save for words\Ghar\20241003_085912.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_085912_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_091420_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_091420_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_091420_slow_down.mp4
# No frames to save for words\Ghar\20241003_091420.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_091420_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_114711_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_114711_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_114711_slow_down.mp4
# No frames to save for words\Ghar\20241003_114711.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_114711_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_115801_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_115801_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_115801_slow_down.mp4
# No frames to save for words\Ghar\20241003_115801.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_115801_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_121202_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_121202_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_121202_slow_down.mp4
# No frames to save for words\Ghar\20241003_121202.mp4
# Saved augmented video at augmented-videos\Ghar\20241003_121202_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241006_083407_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241006_083407_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241006_083407_slow_down.mp4
# No frames to save for words\Ghar\20241006_083407.mp4
# Saved augmented video at augmented-videos\Ghar\20241006_083407_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241006_090918_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241006_090918_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241006_090918_slow_down.mp4
# No frames to save for words\Ghar\20241006_090918.mp4
# Saved augmented video at augmented-videos\Ghar\20241006_090918_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241006_094147_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241006_094147_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241006_094147_slow_down.mp4
# No frames to save for words\Ghar\20241006_094147.mp4
# Saved augmented video at augmented-videos\Ghar\20241006_094147_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241008_091749_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241008_091749_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241008_091749_slow_down.mp4
# No frames to save for words\Ghar\20241008_091749.mp4
# Saved augmented video at augmented-videos\Ghar\20241008_091749_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241008_094242_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241008_094242_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241008_094242_slow_down.mp4
# No frames to save for words\Ghar\20241008_094242.mp4
# Saved augmented video at augmented-videos\Ghar\20241008_094242_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241008_101056_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241008_101056_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241008_101056_slow_down.mp4
# No frames to save for words\Ghar\20241008_101056.mp4
# Saved augmented video at augmented-videos\Ghar\20241008_101056_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241014_093008_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241014_093008_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241014_093008_slow_down.mp4
# No frames to save for words\Ghar\20241014_093008.mp4
# Saved augmented video at augmented-videos\Ghar\20241014_093008_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\20241014_094026_crop.mp4
# Saved augmented video at augmented-videos\Ghar\20241014_094026_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\20241014_094026_slow_down.mp4
# No frames to save for words\Ghar\20241014_094026.mp4
# Saved augmented video at augmented-videos\Ghar\20241014_094026_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\dataset 03 (11)_crop.mp4
# Saved augmented video at augmented-videos\Ghar\dataset 03 (11)_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\dataset 03 (11)_slow_down.mp4
# No frames to save for words\Ghar\dataset 03 (11).mp4
# Saved augmented video at augmented-videos\Ghar\dataset 03 (11)_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\Dataset01 (4)_crop.mp4
# Saved augmented video at augmented-videos\Ghar\Dataset01 (4)_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\Dataset01 (4)_slow_down.mp4
# No frames to save for words\Ghar\Dataset01 (4).mp4
# Saved augmented video at augmented-videos\Ghar\Dataset01 (4)_color_jitter.mp4
# Saved augmented video at augmented-videos\Ghar\Dataset02 (1)_crop.mp4
# Saved augmented video at augmented-videos\Ghar\Dataset02 (1)_speed_up.mp4
# Saved augmented video at augmented-videos\Ghar\Dataset02 (1)_slow_down.mp4
# No frames to save for words\Ghar\Dataset02 (1).mp4
# Saved augmented video at augmented-videos\Ghar\Dataset02 (1)_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241001_152838_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241001_152838_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241001_152838_slow_down.mp4
# No frames to save for words\Gundruk\20241001_152838.mp4
# Saved augmented video at augmented-videos\Gundruk\20241001_152838_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241002_104820_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241002_104820_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241002_104820_slow_down.mp4
# No frames to save for words\Gundruk\20241002_104820.mp4
# Saved augmented video at augmented-videos\Gundruk\20241002_104820_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241002_112212_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241002_112212_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241002_112212_slow_down.mp4
# No frames to save for words\Gundruk\20241002_112212.mp4
# Saved augmented video at augmented-videos\Gundruk\20241002_112212_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241002_121547_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241002_121547_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241002_121547_slow_down.mp4
# No frames to save for words\Gundruk\20241002_121547.mp4
# Saved augmented video at augmented-videos\Gundruk\20241002_121547_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_085859_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_085859_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_085859_slow_down.mp4
# No frames to save for words\Gundruk\20241003_085859.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_085859_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_091411_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_091411_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_091411_slow_down.mp4
# No frames to save for words\Gundruk\20241003_091411.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_091411_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_114656_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_114656_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_114656_slow_down.mp4
# No frames to save for words\Gundruk\20241003_114656.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_114656_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_115746_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_115746_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_115746_slow_down.mp4
# No frames to save for words\Gundruk\20241003_115746.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_115746_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_121150_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_121150_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_121150_slow_down.mp4
# No frames to save for words\Gundruk\20241003_121150.mp4
# Saved augmented video at augmented-videos\Gundruk\20241003_121150_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241006_083351_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241006_083351_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241006_083351_slow_down.mp4
# No frames to save for words\Gundruk\20241006_083351.mp4
# Saved augmented video at augmented-videos\Gundruk\20241006_083351_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241006_090905_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241006_090905_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241006_090905_slow_down.mp4
# No frames to save for words\Gundruk\20241006_090905.mp4
# Saved augmented video at augmented-videos\Gundruk\20241006_090905_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241006_094118_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241006_094118_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241006_094118_slow_down.mp4
# No frames to save for words\Gundruk\20241006_094118.mp4
# Saved augmented video at augmented-videos\Gundruk\20241006_094118_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241008_091738_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241008_091738_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241008_091738_slow_down.mp4
# No frames to save for words\Gundruk\20241008_091738.mp4
# Saved augmented video at augmented-videos\Gundruk\20241008_091738_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241008_094608_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241008_094608_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241008_094608_slow_down.mp4
# No frames to save for words\Gundruk\20241008_094608.mp4
# Saved augmented video at augmented-videos\Gundruk\20241008_094608_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241008_101041_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241008_101041_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241008_101041_slow_down.mp4
# No frames to save for words\Gundruk\20241008_101041.mp4
# Saved augmented video at augmented-videos\Gundruk\20241008_101041_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241014_092954_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241014_092954_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241014_092954_slow_down.mp4
# No frames to save for words\Gundruk\20241014_092954.mp4
# Saved augmented video at augmented-videos\Gundruk\20241014_092954_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\20241014_094010_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\20241014_094010_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\20241014_094010_slow_down.mp4
# No frames to save for words\Gundruk\20241014_094010.mp4
# Saved augmented video at augmented-videos\Gundruk\20241014_094010_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\dataset 03 (10)_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\dataset 03 (10)_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\dataset 03 (10)_slow_down.mp4
# No frames to save for words\Gundruk\dataset 03 (10).mp4
# Saved augmented video at augmented-videos\Gundruk\dataset 03 (10)_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\Dataset01 (17)_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\Dataset01 (17)_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\Dataset01 (17)_slow_down.mp4
# No frames to save for words\Gundruk\Dataset01 (17).mp4
# Saved augmented video at augmented-videos\Gundruk\Dataset01 (17)_color_jitter.mp4
# Saved augmented video at augmented-videos\Gundruk\Dataset02 (15)_crop.mp4
# Saved augmented video at augmented-videos\Gundruk\Dataset02 (15)_speed_up.mp4
# Saved augmented video at augmented-videos\Gundruk\Dataset02 (15)_slow_down.mp4
# No frames to save for words\Gundruk\Dataset02 (15).mp4
# Saved augmented video at augmented-videos\Gundruk\Dataset02 (15)_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241001_152941_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241001_152941_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241001_152941_slow_down.mp4
# No frames to save for words\Guy\20241001_152941.mp4
# Saved augmented video at augmented-videos\Guy\20241001_152941_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241002_104953_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241002_104953_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241002_104953_slow_down.mp4
# No frames to save for words\Guy\20241002_104953.mp4
# Saved augmented video at augmented-videos\Guy\20241002_104953_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241002_112412_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241002_112412_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241002_112412_slow_down.mp4
# No frames to save for words\Guy\20241002_112412.mp4
# Saved augmented video at augmented-videos\Guy\20241002_112412_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241002_121733_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241002_121733_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241002_121733_slow_down.mp4
# No frames to save for words\Guy\20241002_121733.mp4
# Saved augmented video at augmented-videos\Guy\20241002_121733_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241003_090032_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241003_090032_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241003_090032_slow_down.mp4
# No frames to save for words\Guy\20241003_090032.mp4
# Saved augmented video at augmented-videos\Guy\20241003_090032_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241003_091501_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241003_091501_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241003_091501_slow_down.mp4
# No frames to save for words\Guy\20241003_091501.mp4
# Saved augmented video at augmented-videos\Guy\20241003_091501_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241003_114813_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241003_114813_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241003_114813_slow_down.mp4
# No frames to save for words\Guy\20241003_114813.mp4
# Saved augmented video at augmented-videos\Guy\20241003_114813_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241003_115910_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241003_115910_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241003_115910_slow_down.mp4
# No frames to save for words\Guy\20241003_115910.mp4
# Saved augmented video at augmented-videos\Guy\20241003_115910_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241003_121306_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241003_121306_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241003_121306_slow_down.mp4
# No frames to save for words\Guy\20241003_121306.mp4
# Saved augmented video at augmented-videos\Guy\20241003_121306_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241006_083706_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241006_083706_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241006_083706_slow_down.mp4
# No frames to save for words\Guy\20241006_083706.mp4
# Saved augmented video at augmented-videos\Guy\20241006_083706_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241006_091028_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241006_091028_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241006_091028_slow_down.mp4
# No frames to save for words\Guy\20241006_091028.mp4
# Saved augmented video at augmented-videos\Guy\20241006_091028_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241006_094307_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241006_094307_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241006_094307_slow_down.mp4
# No frames to save for words\Guy\20241006_094307.mp4
# Saved augmented video at augmented-videos\Guy\20241006_094307_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241008_091843_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241008_091843_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241008_091843_slow_down.mp4
# No frames to save for words\Guy\20241008_091843.mp4
# Saved augmented video at augmented-videos\Guy\20241008_091843_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241008_094352_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241008_094352_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241008_094352_slow_down.mp4
# No frames to save for words\Guy\20241008_094352.mp4
# Saved augmented video at augmented-videos\Guy\20241008_094352_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241008_101153_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241008_101153_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241008_101153_slow_down.mp4
# No frames to save for words\Guy\20241008_101153.mp4
# Saved augmented video at augmented-videos\Guy\20241008_101153_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241014_093129_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241014_093129_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241014_093129_slow_down.mp4
# No frames to save for words\Guy\20241014_093129.mp4
# Saved augmented video at augmented-videos\Guy\20241014_093129_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\20241014_094118_crop.mp4
# Saved augmented video at augmented-videos\Guy\20241014_094118_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\20241014_094118_slow_down.mp4
# No frames to save for words\Guy\20241014_094118.mp4
# Saved augmented video at augmented-videos\Guy\20241014_094118_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\dataset 03 (1)_crop.mp4
# Saved augmented video at augmented-videos\Guy\dataset 03 (1)_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\dataset 03 (1)_slow_down.mp4
# No frames to save for words\Guy\dataset 03 (1).mp4
# Saved augmented video at augmented-videos\Guy\dataset 03 (1)_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\Dataset01 (11)_crop.mp4
# Saved augmented video at augmented-videos\Guy\Dataset01 (11)_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\Dataset01 (11)_slow_down.mp4
# No frames to save for words\Guy\Dataset01 (11).mp4
# Saved augmented video at augmented-videos\Guy\Dataset01 (11)_color_jitter.mp4
# Saved augmented video at augmented-videos\Guy\Dataset02 (13)_crop.mp4
# Saved augmented video at augmented-videos\Guy\Dataset02 (13)_speed_up.mp4
# Saved augmented video at augmented-videos\Guy\Dataset02 (13)_slow_down.mp4
# No frames to save for words\Guy\Dataset02 (13).mp4
# Saved augmented video at augmented-videos\Guy\Dataset02 (13)_color_jitter.mp4
# Saved augmented video at augmented-videos\Hariyo\20241001_152548_crop.mp4
# Saved augmented video at augmented-videos\Hariyo\20241001_152548_speed_up.mp4
# Saved augmented video at augmented-videos\Hariyo\20241001_152548_slow_down.mp4
# No frames to save for words\Hariyo\20241001_152548.mp4
# Saved augmented video at augmented-videos\Hariyo\20241001_152548_color_jitter.mp4
# Saved augmented video at augmented-videos\Hariyo\20241002_104419_crop.mp4
# Saved augmented video at augmented-videos\Hariyo\20241002_104419_speed_up.mp4
# Saved augmented video at augmented-videos\Hariyo\20241002_104419_slow_down.mp4
# No frames to save for words\Hariyo\20241002_104419.mp4
# Saved augmented video at augmented-videos\Hariyo\20241002_104419_color_jitter.mp4
# Saved augmented video at augmented-videos\Hariyo\20241002_111737_crop.mp4
# Saved augmented video at augmented-videos\Hariyo\20241002_111737_speed_up.mp4
# Saved augmented video at augmented-videos\Hariyo\20241002_111737_slow_down.mp4
# No frames to save for words\Hariyo\20241002_111737.mp4
# Saved augmented video at augmented-videos\Hariyo\20241002_111737_color_jitter.mp4
# Saved augmented video at augmented-videos\Hariyo\20241002_121306_crop.mp4
# Saved augmented video at augmented-videos\Hariyo\20241002_121306_speed_up.mp4
# Saved augmented video at augmented-videos\Hariyo\20241002_121306_slow_down.mp4
# No frames to save for words\Hariyo\20241002_121306.mp4
# Saved augmented video at augmented-videos\Hariyo\20241002_121306_color_jitter.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_085630_crop.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_085630_speed_up.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_085630_slow_down.mp4
# No frames to save for words\Hariyo\20241003_085630.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_085630_color_jitter.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_091247_crop.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_091247_speed_up.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_091247_slow_down.mp4
# No frames to save for words\Hariyo\20241003_091247.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_091247_color_jitter.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_114416_crop.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_114416_speed_up.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_114416_slow_down.mp4
# No frames to save for words\Hariyo\20241003_114416.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_114416_color_jitter.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_115417_crop.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_115417_speed_up.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_115417_slow_down.mp4
# No frames to save for words\Hariyo\20241003_115417.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_115417_color_jitter.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_120942_crop.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_120942_speed_up.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_120942_slow_down.mp4
# No frames to save for words\Hariyo\20241003_120942.mp4
# Saved augmented video at augmented-videos\Hariyo\20241003_120942_color_jitter.mp4
# Saved augmented video at augmented-videos\Hariyo\20241006_082918_crop.mp4
# Saved augmented video at augmented-videos\Hariyo\20241006_082918_speed_up.mp4
# Saved augmented video at augmented-videos\Hariyo\20241006_082918_slow_down.mp4
# No frames to save for words\Hariyo\20241006_082918.mp4
# Saved augmented video at augmented-videos\Hariyo\20241006_082918_color_jitter.mp4
# Saved augmented video at augmented-videos\Hariyo\20241006_090638_crop.mp4
# Saved augmented video at augmented-videos\Hariyo\20241006_090638_speed_up.mp4
# Saved augmented video at augmented-videos\Hariyo\20241006_090638_slow_down.mp4
# No frames to save for words\Hariyo\20241006_090638.mp4
# Saved augmented video at augmented-videos\Hariyo\20241006_090638_color_jitter.mp4
# Saved augmented video at augmented-videos\Hariyo\20241006_093857_crop.mp4
# Saved augmented video at augmented-videos\Hariyo\20241006_093857_speed_up.mp4
# Saved augmented video at augmented-videos\Hariyo\20241006_093857_slow_down.mp4
# No frames to save for words\Hariyo\20241006_093857.mp4
# ...
# Saved augmented video at augmented-videos\Saag\20241014_092939_color_jitter.mp4
# Saved augmented video at augmented-videos\Saag\20241014_093956_crop.mp4
# Saved augmented video at augmented-videos\Saag\20241014_093956_speed_up.mp4
# Saved augmented video at augmented-videos\Saag\20241014_093956_slow_down.mp4
# No frames to save for words\Saag\20241014_093956.mp4
# Saved augmented video at augmented-videos\Saag\20241014_093956_color_jitter.mp4
# Saved augmented video at augmented-videos\Saag\dataset 03 (5)_crop.mp4
# Saved augmented video at augmented-videos\Saag\dataset 03 (5)_speed_up.mp4
# Saved augmented video at augmented-videos\Saag\dataset 03 (5)_slow_down.mp4
# No frames to save for words\Saag\dataset 03 (5).mp4
# Saved augmented video at augmented-videos\Saag\dataset 03 (5)_color_jitter.mp4
# Saved augmented video at augmented-videos\Saag\Dataset01 (5)_crop.mp4
# Saved augmented video at augmented-videos\Saag\Dataset01 (5)_speed_up.mp4
# Saved augmented video at augmented-videos\Saag\Dataset01 (5)_slow_down.mp4
# No frames to save for words\Saag\Dataset01 (5).mp4
# Saved augmented video at augmented-videos\Saag\Dataset01 (5)_color_jitter.mp4
# Saved augmented video at augmented-videos\Saag\Dataset02 (17)_crop.mp4
# Saved augmented video at augmented-videos\Saag\Dataset02 (17)_speed_up.mp4
# Saved augmented video at augmented-videos\Saag\Dataset02 (17)_slow_down.mp4
# No frames to save for words\Saag\Dataset02 (17).mp4
# Saved augmented video at augmented-videos\Saag\Dataset02 (17)_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241001_152633_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241001_152633_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241001_152633_slow_down.mp4
# No frames to save for words\Shau\20241001_152633.mp4
# Saved augmented video at augmented-videos\Shau\20241001_152633_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241002_104457_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241002_104457_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241002_104457_slow_down.mp4
# No frames to save for words\Shau\20241002_104457.mp4
# Saved augmented video at augmented-videos\Shau\20241002_104457_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241002_111824_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241002_111824_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241002_111824_slow_down.mp4
# No frames to save for words\Shau\20241002_111824.mp4
# Saved augmented video at augmented-videos\Shau\20241002_111824_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241002_121343_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241002_121343_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241002_121343_slow_down.mp4
# No frames to save for words\Shau\20241002_121343.mp4
# Saved augmented video at augmented-videos\Shau\20241002_121343_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241003_085731_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241003_085731_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241003_085731_slow_down.mp4
# No frames to save for words\Shau\20241003_085731.mp4
# Saved augmented video at augmented-videos\Shau\20241003_085731_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241003_091326_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241003_091326_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241003_091326_slow_down.mp4
# No frames to save for words\Shau\20241003_091326.mp4
# Saved augmented video at augmented-videos\Shau\20241003_091326_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241003_114452_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241003_114452_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241003_114452_slow_down.mp4
# No frames to save for words\Shau\20241003_114452.mp4
# Saved augmented video at augmented-videos\Shau\20241003_114452_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241003_115529_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241003_115529_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241003_115529_slow_down.mp4
# No frames to save for words\Shau\20241003_115529.mp4
# Saved augmented video at augmented-videos\Shau\20241003_115529_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241003_121017_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241003_121017_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241003_121017_slow_down.mp4
# No frames to save for words\Shau\20241003_121017.mp4
# Saved augmented video at augmented-videos\Shau\20241003_121017_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241006_084540_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241006_084540_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241006_084540_slow_down.mp4
# No frames to save for words\Shau\20241006_084540.mp4
# Saved augmented video at augmented-videos\Shau\20241006_084540_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241006_090711_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241006_090711_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241006_090711_slow_down.mp4
# No frames to save for words\Shau\20241006_090711.mp4
# Saved augmented video at augmented-videos\Shau\20241006_090711_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241006_093952_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241006_093952_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241006_093952_slow_down.mp4
# No frames to save for words\Shau\20241006_093952.mp4
# Saved augmented video at augmented-videos\Shau\20241006_093952_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241008_091616_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241008_091616_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241008_091616_slow_down.mp4
# No frames to save for words\Shau\20241008_091616.mp4
# Saved augmented video at augmented-videos\Shau\20241008_091616_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241008_094017_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241008_094017_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241008_094017_slow_down.mp4
# No frames to save for words\Shau\20241008_094017.mp4
# Saved augmented video at augmented-videos\Shau\20241008_094017_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241008_100913_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241008_100913_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241008_100913_slow_down.mp4
# No frames to save for words\Shau\20241008_100913.mp4
# Saved augmented video at augmented-videos\Shau\20241008_100913_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241014_092738_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241014_092738_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241014_092738_slow_down.mp4
# No frames to save for words\Shau\20241014_092738.mp4
# Saved augmented video at augmented-videos\Shau\20241014_092738_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\20241014_093851_crop.mp4
# Saved augmented video at augmented-videos\Shau\20241014_093851_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\20241014_093851_slow_down.mp4
# No frames to save for words\Shau\20241014_093851.mp4
# Saved augmented video at augmented-videos\Shau\20241014_093851_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\dataset 03 (3)_crop.mp4
# Saved augmented video at augmented-videos\Shau\dataset 03 (3)_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\dataset 03 (3)_slow_down.mp4
# No frames to save for words\Shau\dataset 03 (3).mp4
# Saved augmented video at augmented-videos\Shau\dataset 03 (3)_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\Dataset01 (16)_crop.mp4
# Saved augmented video at augmented-videos\Shau\Dataset01 (16)_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\Dataset01 (16)_slow_down.mp4
# No frames to save for words\Shau\Dataset01 (16).mp4
# Saved augmented video at augmented-videos\Shau\Dataset01 (16)_color_jitter.mp4
# Saved augmented video at augmented-videos\Shau\Dataset02 (11)_crop.mp4
# Saved augmented video at augmented-videos\Shau\Dataset02 (11)_speed_up.mp4
# Saved augmented video at augmented-videos\Shau\Dataset02 (11)_slow_down.mp4
# No frames to save for words\Shau\Dataset02 (11).mp4
# Saved augmented video at augmented-videos\Shau\Dataset02 (11)_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241001_152959_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241001_152959_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241001_152959_slow_down.mp4
# No frames to save for words\Sungur\20241001_152959.mp4
# Saved augmented video at augmented-videos\Sungur\20241001_152959_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241002_105015_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241002_105015_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241002_105015_slow_down.mp4
# No frames to save for words\Sungur\20241002_105015.mp4
# Saved augmented video at augmented-videos\Sungur\20241002_105015_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241002_112442_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241002_112442_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241002_112442_slow_down.mp4
# No frames to save for words\Sungur\20241002_112442.mp4
# Saved augmented video at augmented-videos\Sungur\20241002_112442_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241002_121752_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241002_121752_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241002_121752_slow_down.mp4
# No frames to save for words\Sungur\20241002_121752.mp4
# Saved augmented video at augmented-videos\Sungur\20241002_121752_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_090102_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_090102_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_090102_slow_down.mp4
# No frames to save for words\Sungur\20241003_090102.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_090102_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_091511_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_091511_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_091511_slow_down.mp4
# No frames to save for words\Sungur\20241003_091511.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_091511_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_114826_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_114826_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_114826_slow_down.mp4
# No frames to save for words\Sungur\20241003_114826.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_114826_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_115932_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_115932_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_115932_slow_down.mp4
# No frames to save for words\Sungur\20241003_115932.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_115932_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_121315_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_121315_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_121315_slow_down.mp4
# No frames to save for words\Sungur\20241003_121315.mp4
# Saved augmented video at augmented-videos\Sungur\20241003_121315_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241006_083721_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241006_083721_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241006_083721_slow_down.mp4
# No frames to save for words\Sungur\20241006_083721.mp4
# Saved augmented video at augmented-videos\Sungur\20241006_083721_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241006_091040_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241006_091040_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241006_091040_slow_down.mp4
# No frames to save for words\Sungur\20241006_091040.mp4
# Saved augmented video at augmented-videos\Sungur\20241006_091040_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241006_094319_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241006_094319_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241006_094319_slow_down.mp4
# No frames to save for words\Sungur\20241006_094319.mp4
# Saved augmented video at augmented-videos\Sungur\20241006_094319_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241008_091857_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241008_091857_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241008_091857_slow_down.mp4
# No frames to save for words\Sungur\20241008_091857.mp4
# Saved augmented video at augmented-videos\Sungur\20241008_091857_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241008_094405_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241008_094405_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241008_094405_slow_down.mp4
# No frames to save for words\Sungur\20241008_094405.mp4
# Saved augmented video at augmented-videos\Sungur\20241008_094405_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241008_101208_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241008_101208_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241008_101208_slow_down.mp4
# No frames to save for words\Sungur\20241008_101208.mp4
# Saved augmented video at augmented-videos\Sungur\20241008_101208_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241014_093143_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241014_093143_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241014_093143_slow_down.mp4
# No frames to save for words\Sungur\20241014_093143.mp4
# Saved augmented video at augmented-videos\Sungur\20241014_093143_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\20241014_094128_crop.mp4
# Saved augmented video at augmented-videos\Sungur\20241014_094128_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\20241014_094128_slow_down.mp4
# No frames to save for words\Sungur\20241014_094128.mp4
# Saved augmented video at augmented-videos\Sungur\20241014_094128_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\dataset 03 (9)_crop.mp4
# Saved augmented video at augmented-videos\Sungur\dataset 03 (9)_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\dataset 03 (9)_slow_down.mp4
# No frames to save for words\Sungur\dataset 03 (9).mp4
# Saved augmented video at augmented-videos\Sungur\dataset 03 (9)_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\Dataset01 (19)_crop.mp4
# Saved augmented video at augmented-videos\Sungur\Dataset01 (19)_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\Dataset01 (19)_slow_down.mp4
# No frames to save for words\Sungur\Dataset01 (19).mp4
# Saved augmented video at augmented-videos\Sungur\Dataset01 (19)_color_jitter.mp4
# Saved augmented video at augmented-videos\Sungur\Dataset02 (9)_crop.mp4
# Saved augmented video at augmented-videos\Sungur\Dataset02 (9)_speed_up.mp4
# Saved augmented video at augmented-videos\Sungur\Dataset02 (9)_slow_down.mp4
# No frames to save for words\Sungur\Dataset02 (9).mp4
# Saved augmented video at augmented-videos\Sungur\Dataset02 (9)_color_jitter.mp4
